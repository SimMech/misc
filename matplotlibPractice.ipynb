# %% [markdown]
# > ### <font color=red> Matplotlib </font>

# %%
# %matplotlib notebook               ##by applying this line we will have an interactive navigation in plot
import matplotlib.pyplot as plt
import numpy as np
import random

# %% [markdown]
# ### <font color=red> Histogram </font>

# %%
# Fixing random state for reproducibility
np.random.seed(10000000)

x = 100 + 15 * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=True, color='b', alpha=0.75)

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### <font color=red> Two curves on the same plot </font>

# %%
t=np.arange(0,20,1)

# %%
v1=np.arange(50,70,1)
v1=v1+v1*100*np.random.rand(20)

# %%
v2=np.arange(30,50,1)
v2=v2+v2*100*np.random.rand(20)

# %%
plt.plot(t,v1,t,v2)
plt.plot(t,v1,'v',t,v2,'^k')

# %%
plt.show()   # I don't know why %matplotlib notebook doesn't work here

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as pp
from IPython import display
from ipywidgets import interact, widgets
import re
import mailbox
import csv

# %%
def f(x):
    plt.plot(np.arange(0,24), x*np.arange(0,24))
    plt.ylim(-30,30)
interact(f,x=1)
# Out:
# interactive(children=(IntSlider(value=1, description='x', max=3, min=-1), Output()), _dom_classes=('widget-int…
# <function __main__.f(x)>

# %%
import pandas as pd
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib

# %%
GM=pd.read_csv('C:/Users/fshok/Downloads/GM.csv')
Ford=pd.read_csv('C:/Users/fshok/Downloads/Ford.csv')
GM.Date=pd.to_datetime(GM.Date)
Year=GM.Date.dt.year

# %%
Ford=pd.read_csv('C:/Users/fshok/Downloads/Ford.csv')
Ford.Date=pd.to_datetime(Ford.Date)

# %%
plt.plot(GM.Date,GM.Close,label='GM')
plt.plot(Ford.Date,Ford.Close,label='Ford')
plt.title('Automotive Sector', color='red')
plt.xlabel('Date')
plt.ylabel('Stock')
plt.legend()
plt.grid=True
## matplotlib.axes.Axes.grid(b=None,which='major',axis='X', color='r')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
